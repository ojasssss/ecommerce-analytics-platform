-- %%
-- VALIDATION 1: ADMIN ACCESS CHECK
-- As 'pryeole098@gmail.com', you should see:
-- 1. Real User IDs (Numbers, not hashes)
-- 2. Real Revenue (Numbers, not NULL)
-- 3. All Event Types (including 'purchase')

SELECT 
    user_id, 
    event_type, 
    transaction_amount, 
    brand 
FROM ecommerce_analytics_dev.gold_layer.gold_fact_sales
LIMIT 10;


SELECT * FROM ecommerce_analytics_dev.gold_layer.gold_fact_sales 
WHERE event_type = 'purchase' LIMIT 5;
