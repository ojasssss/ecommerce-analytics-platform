# %% [markdown]
# ![architecture_diagram.drawio_1770747056606.png](./architecture_diagram.drawio_1770747056606.png "architecture_diagram.drawio_1770747056606.png")

# %% [markdown]
# ![Er_Diagram.drawio_1770749103716.png](./Er_Diagram.drawio_1770749103716.png "Er_Diagram.drawio_1770749103716.png")
